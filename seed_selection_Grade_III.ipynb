# %%
import SimpleITK as sitk
import guiPoint
# %matplotlib notebook

# %% [markdown]
# Note: guiPoint.py based on gui.py from simpleITK notebooks samples

# %% [markdown]
# Please enter name of images to import.

# %%
threeD_image = sitk.ReadImage("5308_3D_7_46517.mha")
threeD_image_r = sitk.ReadImage("5308_3D_7_46517_resampled.mha")
T1_image = sitk.ReadImage("5308_T1_8_87925.mha")
T2_image = sitk.ReadImage("5308_T2_3_58051_resampled.mha")
Flair_image = sitk.ReadImage("5308_Flair_5_53041_resampled.mha")

# %% [markdown]
# ## Ventricle Seed Selection

# %%
seeds_aquisition = guiPoint.PointDataAquisition(threeD_image)
# Out:
# <img src="data:image/png;base64,..." width="499.4999851137404">
# A Jupyter Widget

# %%
seeds_ventricle = seeds_aquisition.get_point_indexes()
print(seeds_ventricle)
# Out:
# [(274, 244, 29)]

# %% [markdown]
# ## Tumor Seed Selection

# %% [markdown]
# Please select seeds for each image. Recommend selecting any isolated tumor regions. After seed is selected, please run code directly beneath each gui to obtain seed

# %% [markdown]
# Select seed for 3D image.

# %%
seeds_aquisition1 = guiPoint.PointDataAquisition(threeD_image)
# Out:
# <img src="data:image/png;base64,..." width="499.4999851137404">
# A Jupyter Widget

# %%
seeds_3D = seeds_aquisition1.get_point_indexes()
print(seeds_3D)
# Out:
# [(200, 235, 16)]

# %% [markdown]
# Select seed for T1-weighted image.

# %%
seeds_aquisition2 = guiPoint.PointDataAquisition(T1_image)
# Out:
# <img src="data:image/png;base64,..." width="499.4999851137404">
# A Jupyter Widget

# %%
seeds_T1 = seeds_aquisition2.get_point_indexes()
print(seeds_T1)
# Out:
# [(92, 112, 5)]

# %% [markdown]
# Select seed for T2-weighted image.

# %%
seeds_aquisition3 = guiPoint.PointDataAquisition(T2_image)
# Out:
# <img src="data:image/png;base64,..." width="499.4999851137404">
# A Jupyter Widget

# %%
seeds_T2 = seeds_aquisition3.get_point_indexes()
print(seeds_T2)
# Out:
# []

# %% [markdown]
# Select seed for Flair image.

# %%
seeds_aquisition4 = guiPoint.PointDataAquisition(Flair_image)
# Out:
# <img src="data:image/png;base64,..." width="499.4999851137404">
# A Jupyter Widget

# %%
seeds_flair = seeds_aquisition4.get_point_indexes()
print(seeds_flair)
# Out:
# [(88, 118, 5)]
